# %% [markdown]
# <a href="https://colab.research.google.com/github/priyalpatil31/AML_Priyal_Patil_19/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2, f_classif
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import f_regression

path = "/content/drive/MyDrive/Online_Retail_Small.xlsx"

df = pd.read_excel(path)

df = df.fillna(df.mean(numeric_only=True))

for col in df.select_dtypes(include='object').columns:
    df[col] = df[col].fillna(df[col].mode()[0])
    df[col] = df[col].astype(str)

for col in df.columns:
    if "date" in col.lower():
        df.drop(col, axis=1, inplace=True)

le = LabelEncoder()

for col in df.select_dtypes(include='object').columns:
    df[col] = le.fit_transform(df[col])

X = df.drop('Quantity', axis=1)
y = df['Quantity']

X = X.select_dtypes(include=['int64', 'float64'])

print("\n1. CHI SQUARE")

chi = SelectKBest(score_func=chi2, k=5)
chi.fit(abs(X), y)

print(X.columns[chi.get_support()])

print("\n2. ANOVA F TEST")

anova = SelectKBest(score_func=f_classif, k=5)
anova.fit(X, y)

print(X.columns[anova.get_support()])

print("\n3. MUTUAL INFORMATION")

mi = SelectKBest(score_func=mutual_info_classif, k=5)
mi.fit(X, y)

print(X.columns[mi.get_support()])

print("\n4. VARIANCE THRESHOLD")

vt = VarianceThreshold(threshold=0.1)
vt.fit(X)

print(X.columns[vt.get_support()])

print("\n5. F REGRESSION")

fr = SelectKBest(score_func=f_regression, k=5)
fr.fit(X, y)

print(X.columns[fr.get_support()])
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# 1. CHI SQUARE
# Index(['InvoiceNo', 'StockCode', 'Description', 'UnitPrice', 'CustomerID'], dtype='object')
#
# 2. ANOVA F TEST
# /usr/local/lib/python3.12/dist-packages/sklearn/feature_selection/_univariate_selection.py:111: UserWarning: Features [5] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# /usr/local/lib/python3.12/dist-packages/sklearn/feature_selection/_univariate_selection.py:112: RuntimeWarning: invalid value encountered in divide
#   f = msb / msw
# Index(['InvoiceNo', 'StockCode', 'Description', 'UnitPrice', 'CustomerID'], dtype='object')
#
# 3. MUTUAL INFORMATION
# Index(['InvoiceNo', 'StockCode', 'Description', 'UnitPrice', 'CustomerID'], dtype='object')
#
# 4. VARIANCE THRESHOLD
# Index(['InvoiceNo', 'StockCode', 'Description', 'UnitPrice', 'CustomerID'], dtype='object')
#
# ...
